# %% [markdown]
# # [Demo] Robust Node Classification on Graphs: Jointly from Bayesian Label Transition and Topology-based Label Propagation (LInDT)

# %% [markdown]
# ### Authors: Jun Zhuang, Mohammad Al Hasan
# ```
# The paper is accepted for CIKM 2022
# ```

# %%
import os
import sys
import time
import argparse
from datetime import datetime
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import dgl
from sklearn.metrics import accuracy_score, f1_score
from scipy.stats import entropy
from load_data import LoadDataset
from models_GNN import GNN
from models_LInDT import LInDT
from train_GNN import train, evaluation, prediction
from rdmPert import random_connections
from utils import read_yaml_file, read_pickle, dump_pickle, split_masks, generate_random_noise_label, \
                    load_checkpoint, save_checkpoint, count_parameters, \
                    compute_accuracy, compute_f1_score, dist_pre_class, compute_entropy, \
                    compute_edge_homo_ratio, select_target_nodes, \
                    gen_init_trans_matrix

# %%
# Read config files for training
config_file1 = read_yaml_file("../config", "model_lindt")
assert config_file1
train_gnn_config = config_file1["train_gnn"]
data_name = train_gnn_config["data_name"]
model_name = train_gnn_config["model_name"]
NOISE_RATIO = train_gnn_config["NOISE_RATIO"]
NUM_EPOCHS = train_gnn_config["NUM_EPOCHS"]
is_trainable = train_gnn_config["is_trainable"]
GPU = train_gnn_config["GPU"]

# Read config files for perturbations
config_file2 = read_yaml_file("../config", "perturbations")
assert config_file2
pert_config = config_file2["rdmPert"]
TARGET_CLASS = pert_config["TARGET_CLASS"]
SAMPLE_RATE = pert_config["SAMPLE_RATE"]

# Read config files for inference
infer_config = config_file1["inference"]
pert_type = infer_config["pert_type"]
attack_type = infer_config["attack_type"]
is_inferable = infer_config["is_inferable"]
infer_type = infer_config["infer_type"]
topo_type = infer_config["topo_type"]
NUM_EPS = infer_config["NUM_EPS"]
NUM_RETRAIN = infer_config["NUM_RETRAIN"]
WARMUP_STEP = infer_config["WARMUP_STEP"]
is_alert = infer_config["is_alert"]
is_dynamic_phi = infer_config["is_dynamic_phi"]
is_dynamic_alpha = infer_config["is_dynamic_alpha"]
ALPHA = infer_config["ALPHA"]

# Initialize the parameters
CUT_RATE = [0.1, 0.2]  # the split ratio of train/validation mask.
LR = 0.001
N_LAYERS = 2
N_HIDDEN = 200
DROPOUT = 0
WEIGHT_DECAY = 0
kwargs_dicts = {"GCN": [None, None, None],  # aggregator_type, n_filter, n_heads.
                "GraphSAGE": ["gcn", None, None],
                "SGC": [None, 2, None],
                "GAT": [None, None, 3]}
topo_dicts = {"random": "random_kernel",
               "major": "majority_kernel",
               "degree": "degree_weighted_kernel"}
Kernel_Type = topo_dicts[topo_type] if topo_type in topo_dicts.keys() else ""
PERT_RATE = 0.01  # num_perturbators cannot exceed this ratio
assert SAMPLE_RATE + PERT_RATE <= 1.0
dirs_attack = '../data/attacker_data/'

# %% [markdown]
# ## Train the node classifier

# %%
# Load dataset
data = LoadDataset(data_name)
graph = data.load_data()
feat, label = graph.ndata['feat'], graph.ndata['label']
print("Class ID: ", set(label.numpy()))
# Randomly split the train, validation, test mask by given cut rate
train_mask, val_mask, test_mask = split_masks(label, cut_rate=CUT_RATE)
# Generate noisy label
Y_noisy = generate_random_noise_label(label, noisy_ratio=NOISE_RATIO, seed=0)
Y_noisy = torch.LongTensor(Y_noisy)
dump_pickle('../data/noisy_label/Y_gt_noisy_masks.pkl', \
            [label, Y_noisy, train_mask, val_mask, test_mask])
# Display the variables
print("""-------Data statistics-------'
      # Nodes: {0}
      # Edges: {1}
      # Features: {2}
      # Classes: {3}
      # Train samples: {4}
      # Val samples: {5}
      # Test samples: {6}
      # The edge homophily ratio: {7}%
      """.format(graph.number_of_nodes(), graph.number_of_edges(),\
                 feat.shape[1], len(torch.unique(label)), \
                  train_mask.int().sum().item(), \
                  val_mask.int().sum().item(), \
                  test_mask.int().sum().item(), \
                  np.round(compute_edge_homo_ratio(graph, label)*100, 2)
                  ))

# Setup the gpu if necessary
if GPU < 0:
    print("Using CPU!")
    cuda = False
else:
    print("Using GPU!")
    cuda = True
    torch.cuda.set_device(GPU)
    graph = graph.to('cuda')
    feat = feat.cuda()
    label = label.cuda()
    Y_noisy = Y_noisy.cuda()
    train_mask = train_mask.cuda()
    val_mask = val_mask.cuda()
    test_mask = test_mask.cuda()

# Initialize the node classifier
model = GNN(g=graph,
            in_feats=feat.shape[1],
            n_hidden=N_HIDDEN,
            n_classes=len(torch.unique(label)),
            n_layers=N_LAYERS,
            activation=F.relu,
            dropout=DROPOUT,
            model_name=model_name,
            aggregator_type=kwargs_dicts[model_name][0],
            n_filter=kwargs_dicts[model_name][1],
            n_heads=kwargs_dicts[model_name][2])
print(model)
print(f'The model has {count_parameters(model):,} trainable parameters.')
if cuda:  # if gpu is available
    model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
# Path for saving the parameters
dirs = 'runs/{0}_{1}/'.format(data_name, model_name)
path = dirs + 'model_best.pth.tar'

# Training the model
if is_trainable:
    train(model, optimizer, dirs, feat, Y_noisy, train_mask, val_mask, NUM_EPOCHS)
    # Save the weights of current model
    W0, W1 = model.w0.cpu(), model.w1.cpu()
    dump_pickle('../data/attacker_data/W_{0}_{1}.pkl'\
                .format(data_name, model_name),
                [W0.detach().numpy(), W1.detach().numpy()])

# Evaluation
print("Evaluation on stationary graphs!")
evaluation(model, optimizer, path, graph, feat, label, test_mask, cuda)
# Generate and save predicted labels
Y_pred, Y_pred_sm = prediction(model, optimizer, path, graph, feat)  # prediction on all nodes
if cuda:
    Y_pred, Y_pred_sm = Y_pred.cpu(), Y_pred_sm.cpu()
dump_pickle('../data/noisy_label/Y_preds.pkl', [Y_pred, Y_pred_sm])
print("Y_pred/Y_pred_sm.shape: ", Y_pred.shape, Y_pred_sm.shape)
# Out:
# Current dataset: cora, citeseer, pubmed, amazoncobuy, coauthor, reddit.
# Selecting cora Dataset ...
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# Data is stored in: /Users/[user_name]/.dgl
# cora Dataset Loaded!
# Class ID:  {0, 1, 2, 3, 4, 5, 6}
# -------Data statistics-------'
#       # Nodes: 2708
#       # Edges: 13264
#       # Features: 1433
#       # Classes: 7
#       # Train samples: 270
#       # Val samples: 542
#       # Test samples: 1896
#       # The edge homophily ratio: 81.0%
#
# Using CPU!
# GNN(
#   (layers): ModuleList(
#     (0): GraphConv(in=1433, out=200, normalization=both, activation=<function relu at 0x7fb48f9644c0>)
#     (1): Dropout(p=0, inplace=False)
#     (2): GraphConv(in=200, out=200, normalization=both, activation=<function relu at 0x7fb48f9644c0>)
#     (3): Dropout(p=0, inplace=False)
#     (4): GraphConv(in=200, out=7, normalization=both, activation=None)
#   )
# )
# The model has 328,407 trainable parameters.
# Model parameter is not found.
# Epoch 00001 | Time(s) nan | Train Loss 1.9455 | Val Loss 1.9457 | Train Accuracy 0.1593 | Val Accuracy 0.1531
# /Users/junzhuang/opt/miniconda3/envs/py39/lib/python3.9/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# /Users/junzhuang/opt/miniconda3/envs/py39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/junzhuang/opt/miniconda3/envs/py39/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00002 | Time(s) nan | Train Loss 1.9401 | Val Loss 1.9413 | Train Accuracy 0.3074 | Val Accuracy 0.2915
# Epoch 00003 | Time(s) 0.1048 | Train Loss 1.9349 | Val Loss 1.9369 | Train Accuracy 0.2963 | Val Accuracy 0.2934
# Epoch 00004 | Time(s) 0.0873 | Train Loss 1.9292 | Val Loss 1.9322 | Train Accuracy 0.2963 | Val Accuracy 0.2952
# Epoch 00005 | Time(s) 0.0806 | Train Loss 1.9227 | Val Loss 1.9268 | Train Accuracy 0.2926 | Val Accuracy 0.2952
# Epoch 00006 | Time(s) 0.0770 | Train Loss 1.9155 | Val Loss 1.9208 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00007 | Time(s) 0.0741 | Train Loss 1.9074 | Val Loss 1.9142 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00008 | Time(s) 0.0729 | Train Loss 1.8985 | Val Loss 1.9068 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00009 | Time(s) 0.0719 | Train Loss 1.8886 | Val Loss 1.8988 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00010 | Time(s) 0.0713 | Train Loss 1.8779 | Val Loss 1.8902 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00011 | Time(s) 0.0708 | Train Loss 1.8665 | Val Loss 1.8810 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00012 | Time(s) 0.0703 | Train Loss 1.8543 | Val Loss 1.8713 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00013 | Time(s) 0.0696 | Train Loss 1.8415 | Val Loss 1.8613 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00014 | Time(s) 0.0692 | Train Loss 1.8283 | Val Loss 1.8512 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00015 | Time(s) 0.0687 | Train Loss 1.8148 | Val Loss 1.8411 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00016 | Time(s) 0.0684 | Train Loss 1.8012 | Val Loss 1.8312 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00017 | Time(s) 0.0681 | Train Loss 1.7878 | Val Loss 1.8218 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00018 | Time(s) 0.0677 | Train Loss 1.7748 | Val Loss 1.8130 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00019 | Time(s) 0.0674 | Train Loss 1.7624 | Val Loss 1.8050 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00020 | Time(s) 0.0673 | Train Loss 1.7506 | Val Loss 1.7977 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00021 | Time(s) 0.0671 | Train Loss 1.7392 | Val Loss 1.7910 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00022 | Time(s) 0.0671 | Train Loss 1.7282 | Val Loss 1.7845 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00023 | Time(s) 0.0669 | Train Loss 1.7170 | Val Loss 1.7777 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00024 | Time(s) 0.0672 | Train Loss 1.7052 | Val Loss 1.7702 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00025 | Time(s) 0.0670 | Train Loss 1.6924 | Val Loss 1.7615 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00026 | Time(s) 0.0669 | Train Loss 1.6784 | Val Loss 1.7514 | Train Accuracy 0.2889 | Val Accuracy 0.2934
# Epoch 00027 | Time(s) 0.0667 | Train Loss 1.6633 | Val Loss 1.7400 | Train Accuracy 0.3000 | Val Accuracy 0.2915
# Epoch 00028 | Time(s) 0.0666 | Train Loss 1.6471 | Val Loss 1.7275 | Train Accuracy 0.3222 | Val Accuracy 0.3007
# Epoch 00029 | Time(s) 0.0664 | Train Loss 1.6301 | Val Loss 1.7143 | Train Accuracy 0.3481 | Val Accuracy 0.3081
# Epoch 00030 | Time(s) 0.0663 | Train Loss 1.6124 | Val Loss 1.7004 | Train Accuracy 0.3593 | Val Accuracy 0.3284
# Epoch 00031 | Time(s) 0.0662 | Train Loss 1.5941 | Val Loss 1.6861 | Train Accuracy 0.3741 | Val Accuracy 0.3395
# Epoch 00032 | Time(s) 0.0661 | Train Loss 1.5751 | Val Loss 1.6714 | Train Accuracy 0.3926 | Val Accuracy 0.3542
# Epoch 00033 | Time(s) 0.0661 | Train Loss 1.5555 | Val Loss 1.6564 | Train Accuracy 0.4222 | Val Accuracy 0.3598
# Epoch 00034 | Time(s) 0.0661 | Train Loss 1.5352 | Val Loss 1.6410 | Train Accuracy 0.4593 | Val Accuracy 0.3801
# Epoch 00035 | Time(s) 0.0661 | Train Loss 1.5140 | Val Loss 1.6251 | Train Accuracy 0.4926 | Val Accuracy 0.4004
# Epoch 00036 | Time(s) 0.0661 | Train Loss 1.4919 | Val Loss 1.6089 | Train Accuracy 0.5148 | Val Accuracy 0.4151
# Epoch 00037 | Time(s) 0.0660 | Train Loss 1.4689 | Val Loss 1.5922 | Train Accuracy 0.5333 | Val Accuracy 0.4373
# Epoch 00038 | Time(s) 0.0660 | Train Loss 1.4451 | Val Loss 1.5751 | Train Accuracy 0.5370 | Val Accuracy 0.4465
# Epoch 00039 | Time(s) 0.0659 | Train Loss 1.4205 | Val Loss 1.5577 | Train Accuracy 0.5519 | Val Accuracy 0.4483
# Epoch 00040 | Time(s) 0.0659 | Train Loss 1.3953 | Val Loss 1.5402 | Train Accuracy 0.5593 | Val Accuracy 0.4557
# Epoch 00041 | Time(s) 0.0660 | Train Loss 1.3696 | Val Loss 1.5225 | Train Accuracy 0.5593 | Val Accuracy 0.4613
# Epoch 00042 | Time(s) 0.0659 | Train Loss 1.3435 | Val Loss 1.5046 | Train Accuracy 0.5815 | Val Accuracy 0.4649
# Epoch 00043 | Time(s) 0.0659 | Train Loss 1.3172 | Val Loss 1.4866 | Train Accuracy 0.5852 | Val Accuracy 0.4686
# Epoch 00044 | Time(s) 0.0659 | Train Loss 1.2906 | Val Loss 1.4685 | Train Accuracy 0.5963 | Val Accuracy 0.4668
# Epoch 00045 | Time(s) 0.0658 | Train Loss 1.2638 | Val Loss 1.4500 | Train Accuracy 0.6111 | Val Accuracy 0.4742
# Epoch 00046 | Time(s) 0.0658 | Train Loss 1.2369 | Val Loss 1.4313 | Train Accuracy 0.6222 | Val Accuracy 0.4945
# Epoch 00047 | Time(s) 0.0658 | Train Loss 1.2100 | Val Loss 1.4124 | Train Accuracy 0.6444 | Val Accuracy 0.5074
# Epoch 00048 | Time(s) 0.0658 | Train Loss 1.1830 | Val Loss 1.3936 | Train Accuracy 0.6667 | Val Accuracy 0.5258
# Epoch 00049 | Time(s) 0.0657 | Train Loss 1.1562 | Val Loss 1.3748 | Train Accuracy 0.6852 | Val Accuracy 0.5498
# Epoch 00050 | Time(s) 0.0657 | Train Loss 1.1295 | Val Loss 1.3561 | Train Accuracy 0.7000 | Val Accuracy 0.5646
# Epoch 00051 | Time(s) 0.0656 | Train Loss 1.1029 | Val Loss 1.3377 | Train Accuracy 0.7222 | Val Accuracy 0.5867
# Epoch 00052 | Time(s) 0.0656 | Train Loss 1.0765 | Val Loss 1.3196 | Train Accuracy 0.7333 | Val Accuracy 0.6089
# Epoch 00053 | Time(s) 0.0656 | Train Loss 1.0503 | Val Loss 1.3019 | Train Accuracy 0.7370 | Val Accuracy 0.6144
# Epoch 00054 | Time(s) 0.0656 | Train Loss 1.0244 | Val Loss 1.2849 | Train Accuracy 0.7481 | Val Accuracy 0.6255
# Epoch 00055 | Time(s) 0.0656 | Train Loss 0.9988 | Val Loss 1.2683 | Train Accuracy 0.7630 | Val Accuracy 0.6328
# Epoch 00056 | Time(s) 0.0655 | Train Loss 0.9735 | Val Loss 1.2523 | Train Accuracy 0.7704 | Val Accuracy 0.6421
# Epoch 00057 | Time(s) 0.0655 | Train Loss 0.9484 | Val Loss 1.2367 | Train Accuracy 0.7704 | Val Accuracy 0.6439
# Epoch 00058 | Time(s) 0.0655 | Train Loss 0.9237 | Val Loss 1.2215 | Train Accuracy 0.7741 | Val Accuracy 0.6421
# Epoch 00059 | Time(s) 0.0655 | Train Loss 0.8994 | Val Loss 1.2066 | Train Accuracy 0.7852 | Val Accuracy 0.6550
# Epoch 00060 | Time(s) 0.0655 | Train Loss 0.8754 | Val Loss 1.1920 | Train Accuracy 0.7926 | Val Accuracy 0.6513
# Epoch 00061 | Time(s) 0.0655 | Train Loss 0.8518 | Val Loss 1.1778 | Train Accuracy 0.8037 | Val Accuracy 0.6587
# Epoch 00062 | Time(s) 0.0655 | Train Loss 0.8286 | Val Loss 1.1639 | Train Accuracy 0.8148 | Val Accuracy 0.6679
# Epoch 00063 | Time(s) 0.0655 | Train Loss 0.8058 | Val Loss 1.1505 | Train Accuracy 0.8333 | Val Accuracy 0.6679
# Epoch 00064 | Time(s) 0.0656 | Train Loss 0.7835 | Val Loss 1.1376 | Train Accuracy 0.8444 | Val Accuracy 0.6697
# Epoch 00065 | Time(s) 0.0656 | Train Loss 0.7615 | Val Loss 1.1251 | Train Accuracy 0.8444 | Val Accuracy 0.6716
# Epoch 00066 | Time(s) 0.0656 | Train Loss 0.7400 | Val Loss 1.1132 | Train Accuracy 0.8444 | Val Accuracy 0.6790
# Epoch 00067 | Time(s) 0.0656 | Train Loss 0.7189 | Val Loss 1.1020 | Train Accuracy 0.8444 | Val Accuracy 0.6808
# Epoch 00068 | Time(s) 0.0655 | Train Loss 0.6982 | Val Loss 1.0914 | Train Accuracy 0.8556 | Val Accuracy 0.6827
# Epoch 00069 | Time(s) 0.0655 | Train Loss 0.6781 | Val Loss 1.0815 | Train Accuracy 0.8593 | Val Accuracy 0.6827
# Epoch 00070 | Time(s) 0.0655 | Train Loss 0.6585 | Val Loss 1.0722 | Train Accuracy 0.8593 | Val Accuracy 0.6882
# Epoch 00071 | Time(s) 0.0655 | Train Loss 0.6395 | Val Loss 1.0636 | Train Accuracy 0.8704 | Val Accuracy 0.6919
# Epoch 00072 | Time(s) 0.0655 | Train Loss 0.6209 | Val Loss 1.0556 | Train Accuracy 0.8667 | Val Accuracy 0.6956
# Epoch 00073 | Time(s) 0.0655 | Train Loss 0.6028 | Val Loss 1.0481 | Train Accuracy 0.8704 | Val Accuracy 0.6993
# Epoch 00074 | Time(s) 0.0655 | Train Loss 0.5852 | Val Loss 1.0411 | Train Accuracy 0.8704 | Val Accuracy 0.7011
# Epoch 00075 | Time(s) 0.0655 | Train Loss 0.5681 | Val Loss 1.0346 | Train Accuracy 0.8704 | Val Accuracy 0.7085
# Epoch 00076 | Time(s) 0.0655 | Train Loss 0.5515 | Val Loss 1.0286 | Train Accuracy 0.8741 | Val Accuracy 0.7103
# Epoch 00077 | Time(s) 0.0654 | Train Loss 0.5353 | Val Loss 1.0231 | Train Accuracy 0.8778 | Val Accuracy 0.7085
# Epoch 00078 | Time(s) 0.0654 | Train Loss 0.5196 | Val Loss 1.0182 | Train Accuracy 0.8778 | Val Accuracy 0.7085
# Epoch 00079 | Time(s) 0.0654 | Train Loss 0.5044 | Val Loss 1.0139 | Train Accuracy 0.8852 | Val Accuracy 0.7103
# Epoch 00080 | Time(s) 0.0653 | Train Loss 0.4895 | Val Loss 1.0100 | Train Accuracy 0.8889 | Val Accuracy 0.7103
# Epoch 00081 | Time(s) 0.0653 | Train Loss 0.4752 | Val Loss 1.0067 | Train Accuracy 0.8889 | Val Accuracy 0.7085
# Epoch 00082 | Time(s) 0.0653 | Train Loss 0.4612 | Val Loss 1.0039 | Train Accuracy 0.9037 | Val Accuracy 0.7122
# Epoch 00083 | Time(s) 0.0653 | Train Loss 0.4477 | Val Loss 1.0015 | Train Accuracy 0.9037 | Val Accuracy 0.7122
# Epoch 00084 | Time(s) 0.0653 | Train Loss 0.4346 | Val Loss 0.9996 | Train Accuracy 0.9074 | Val Accuracy 0.7159
# Epoch 00085 | Time(s) 0.0653 | Train Loss 0.4218 | Val Loss 0.9981 | Train Accuracy 0.9111 | Val Accuracy 0.7196
# Epoch 00086 | Time(s) 0.0654 | Train Loss 0.4095 | Val Loss 0.9970 | Train Accuracy 0.9148 | Val Accuracy 0.7214
# Epoch 00087 | Time(s) 0.0653 | Train Loss 0.3976 | Val Loss 0.9963 | Train Accuracy 0.9185 | Val Accuracy 0.7232
# Epoch 00088 | Time(s) 0.0653 | Train Loss 0.3860 | Val Loss 0.9959 | Train Accuracy 0.9185 | Val Accuracy 0.7196
# Epoch 00089 | Time(s) 0.0653 | Train Loss 0.3747 | Val Loss 0.9959 | Train Accuracy 0.9185 | Val Accuracy 0.7232
# Epoch 00090 | Time(s) 0.0653 | Train Loss 0.3639 | Val Loss 0.9963 | Train Accuracy 0.9222 | Val Accuracy 0.7251
# Epoch 00091 | Time(s) 0.0653 | Train Loss 0.3533 | Val Loss 0.9971 | Train Accuracy 0.9296 | Val Accuracy 0.7232
# Epoch 00092 | Time(s) 0.0653 | Train Loss 0.3431 | Val Loss 0.9982 | Train Accuracy 0.9296 | Val Accuracy 0.7251
# Epoch 00093 | Time(s) 0.0653 | Train Loss 0.3332 | Val Loss 0.9997 | Train Accuracy 0.9333 | Val Accuracy 0.7288
# Epoch 00094 | Time(s) 0.0653 | Train Loss 0.3236 | Val Loss 1.0015 | Train Accuracy 0.9333 | Val Accuracy 0.7325
# Epoch 00095 | Time(s) 0.0653 | Train Loss 0.3143 | Val Loss 1.0036 | Train Accuracy 0.9370 | Val Accuracy 0.7343
# Epoch 00096 | Time(s) 0.0653 | Train Loss 0.3053 | Val Loss 1.0059 | Train Accuracy 0.9370 | Val Accuracy 0.7362
# Epoch 00097 | Time(s) 0.0652 | Train Loss 0.2965 | Val Loss 1.0084 | Train Accuracy 0.9407 | Val Accuracy 0.7380
# Epoch 00098 | Time(s) 0.0652 | Train Loss 0.2881 | Val Loss 1.0111 | Train Accuracy 0.9481 | Val Accuracy 0.7417
# Epoch 00099 | Time(s) 0.0653 | Train Loss 0.2799 | Val Loss 1.0140 | Train Accuracy 0.9481 | Val Accuracy 0.7399
# Epoch 00100 | Time(s) 0.0653 | Train Loss 0.2720 | Val Loss 1.0171 | Train Accuracy 0.9519 | Val Accuracy 0.7380
# Epoch 00101 | Time(s) 0.0653 | Train Loss 0.2644 | Val Loss 1.0204 | Train Accuracy 0.9519 | Val Accuracy 0.7362
# Epoch 00102 | Time(s) 0.0653 | Train Loss 0.2570 | Val Loss 1.0239 | Train Accuracy 0.9519 | Val Accuracy 0.7399
# Epoch 00103 | Time(s) 0.0653 | Train Loss 0.2498 | Val Loss 1.0276 | Train Accuracy 0.9556 | Val Accuracy 0.7399
# Epoch 00104 | Time(s) 0.0653 | Train Loss 0.2429 | Val Loss 1.0315 | Train Accuracy 0.9556 | Val Accuracy 0.7454
# Epoch 00105 | Time(s) 0.0653 | Train Loss 0.2361 | Val Loss 1.0355 | Train Accuracy 0.9593 | Val Accuracy 0.7435
# Epoch 00106 | Time(s) 0.0653 | Train Loss 0.2296 | Val Loss 1.0396 | Train Accuracy 0.9630 | Val Accuracy 0.7454
# Epoch 00107 | Time(s) 0.0653 | Train Loss 0.2233 | Val Loss 1.0438 | Train Accuracy 0.9630 | Val Accuracy 0.7454
# Epoch 00108 | Time(s) 0.0653 | Train Loss 0.2172 | Val Loss 1.0481 | Train Accuracy 0.9630 | Val Accuracy 0.7417
# Epoch 00109 | Time(s) 0.0652 | Train Loss 0.2113 | Val Loss 1.0524 | Train Accuracy 0.9630 | Val Accuracy 0.7399
# Epoch 00110 | Time(s) 0.0652 | Train Loss 0.2055 | Val Loss 1.0567 | Train Accuracy 0.9630 | Val Accuracy 0.7417
# Epoch 00111 | Time(s) 0.0652 | Train Loss 0.2000 | Val Loss 1.0610 | Train Accuracy 0.9630 | Val Accuracy 0.7399
# Epoch 00112 | Time(s) 0.0652 | Train Loss 0.1946 | Val Loss 1.0654 | Train Accuracy 0.9630 | Val Accuracy 0.7380
# Epoch 00113 | Time(s) 0.0652 | Train Loss 0.1893 | Val Loss 1.0699 | Train Accuracy 0.9630 | Val Accuracy 0.7343
# Epoch 00114 | Time(s) 0.0652 | Train Loss 0.1842 | Val Loss 1.0744 | Train Accuracy 0.9630 | Val Accuracy 0.7343
# Epoch 00115 | Time(s) 0.0652 | Train Loss 0.1793 | Val Loss 1.0789 | Train Accuracy 0.9630 | Val Accuracy 0.7343
# Epoch 00116 | Time(s) 0.0652 | Train Loss 0.1745 | Val Loss 1.0835 | Train Accuracy 0.9667 | Val Accuracy 0.7343
# Epoch 00117 | Time(s) 0.0652 | Train Loss 0.1699 | Val Loss 1.0881 | Train Accuracy 0.9667 | Val Accuracy 0.7343
# Epoch 00118 | Time(s) 0.0652 | Train Loss 0.1654 | Val Loss 1.0927 | Train Accuracy 0.9704 | Val Accuracy 0.7343
# Epoch 00119 | Time(s) 0.0652 | Train Loss 0.1610 | Val Loss 1.0974 | Train Accuracy 0.9741 | Val Accuracy 0.7325
# Epoch 00120 | Time(s) 0.0652 | Train Loss 0.1568 | Val Loss 1.1021 | Train Accuracy 0.9741 | Val Accuracy 0.7343
# Epoch 00121 | Time(s) 0.0652 | Train Loss 0.1527 | Val Loss 1.1067 | Train Accuracy 0.9741 | Val Accuracy 0.7306
# Epoch 00122 | Time(s) 0.0652 | Train Loss 0.1488 | Val Loss 1.1114 | Train Accuracy 0.9741 | Val Accuracy 0.7325
# Epoch 00123 | Time(s) 0.0652 | Train Loss 0.1449 | Val Loss 1.1161 | Train Accuracy 0.9741 | Val Accuracy 0.7306
# Epoch 00124 | Time(s) 0.0651 | Train Loss 0.1412 | Val Loss 1.1208 | Train Accuracy 0.9741 | Val Accuracy 0.7306
# Epoch 00125 | Time(s) 0.0651 | Train Loss 0.1376 | Val Loss 1.1255 | Train Accuracy 0.9741 | Val Accuracy 0.7306
# Epoch 00126 | Time(s) 0.0651 | Train Loss 0.1341 | Val Loss 1.1302 | Train Accuracy 0.9741 | Val Accuracy 0.7306
# Epoch 00127 | Time(s) 0.0651 | Train Loss 0.1307 | Val Loss 1.1350 | Train Accuracy 0.9741 | Val Accuracy 0.7325
# Epoch 00128 | Time(s) 0.0651 | Train Loss 0.1274 | Val Loss 1.1397 | Train Accuracy 0.9741 | Val Accuracy 0.7343
# Epoch 00129 | Time(s) 0.0651 | Train Loss 0.1243 | Val Loss 1.1446 | Train Accuracy 0.9741 | Val Accuracy 0.7343
# Epoch 00130 | Time(s) 0.0651 | Train Loss 0.1212 | Val Loss 1.1494 | Train Accuracy 0.9741 | Val Accuracy 0.7343
# Epoch 00131 | Time(s) 0.0652 | Train Loss 0.1182 | Val Loss 1.1542 | Train Accuracy 0.9741 | Val Accuracy 0.7343
# Epoch 00132 | Time(s) 0.0652 | Train Loss 0.1153 | Val Loss 1.1591 | Train Accuracy 0.9741 | Val Accuracy 0.7325
# Epoch 00133 | Time(s) 0.0652 | Train Loss 0.1125 | Val Loss 1.1639 | Train Accuracy 0.9741 | Val Accuracy 0.7325
# Epoch 00134 | Time(s) 0.0652 | Train Loss 0.1098 | Val Loss 1.1688 | Train Accuracy 0.9741 | Val Accuracy 0.7325
# Epoch 00135 | Time(s) 0.0651 | Train Loss 0.1072 | Val Loss 1.1737 | Train Accuracy 0.9815 | Val Accuracy 0.7325
# Epoch 00136 | Time(s) 0.0651 | Train Loss 0.1046 | Val Loss 1.1785 | Train Accuracy 0.9815 | Val Accuracy 0.7325
# Epoch 00137 | Time(s) 0.0651 | Train Loss 0.1022 | Val Loss 1.1834 | Train Accuracy 0.9778 | Val Accuracy 0.7325
# Epoch 00138 | Time(s) 0.0651 | Train Loss 0.0998 | Val Loss 1.1882 | Train Accuracy 0.9778 | Val Accuracy 0.7325
# Epoch 00139 | Time(s) 0.0651 | Train Loss 0.0974 | Val Loss 1.1931 | Train Accuracy 0.9778 | Val Accuracy 0.7325
# Epoch 00140 | Time(s) 0.0651 | Train Loss 0.0952 | Val Loss 1.1980 | Train Accuracy 0.9778 | Val Accuracy 0.7343
# Epoch 00141 | Time(s) 0.0651 | Train Loss 0.0930 | Val Loss 1.2029 | Train Accuracy 0.9852 | Val Accuracy 0.7325
# Epoch 00142 | Time(s) 0.0651 | Train Loss 0.0909 | Val Loss 1.2078 | Train Accuracy 0.9852 | Val Accuracy 0.7343
# Epoch 00143 | Time(s) 0.0651 | Train Loss 0.0888 | Val Loss 1.2128 | Train Accuracy 0.9852 | Val Accuracy 0.7325
# Epoch 00144 | Time(s) 0.0651 | Train Loss 0.0868 | Val Loss 1.2177 | Train Accuracy 0.9852 | Val Accuracy 0.7325
# Epoch 00145 | Time(s) 0.0651 | Train Loss 0.0849 | Val Loss 1.2226 | Train Accuracy 0.9852 | Val Accuracy 0.7325
# Epoch 00146 | Time(s) 0.0651 | Train Loss 0.0830 | Val Loss 1.2275 | Train Accuracy 0.9852 | Val Accuracy 0.7325
# Epoch 00147 | Time(s) 0.0651 | Train Loss 0.0812 | Val Loss 1.2324 | Train Accuracy 0.9852 | Val Accuracy 0.7325
# Epoch 00148 | Time(s) 0.0651 | Train Loss 0.0794 | Val Loss 1.2372 | Train Accuracy 0.9852 | Val Accuracy 0.7325
# Epoch 00149 | Time(s) 0.0651 | Train Loss 0.0777 | Val Loss 1.2421 | Train Accuracy 0.9889 | Val Accuracy 0.7325
# Epoch 00150 | Time(s) 0.0651 | Train Loss 0.0761 | Val Loss 1.2469 | Train Accuracy 0.9889 | Val Accuracy 0.7325
# Epoch 00151 | Time(s) 0.0651 | Train Loss 0.0744 | Val Loss 1.2517 | Train Accuracy 0.9889 | Val Accuracy 0.7325
# Epoch 00152 | Time(s) 0.0651 | Train Loss 0.0729 | Val Loss 1.2565 | Train Accuracy 0.9889 | Val Accuracy 0.7306
# Epoch 00153 | Time(s) 0.0651 | Train Loss 0.0713 | Val Loss 1.2613 | Train Accuracy 0.9889 | Val Accuracy 0.7306
# Epoch 00154 | Time(s) 0.0652 | Train Loss 0.0699 | Val Loss 1.2661 | Train Accuracy 0.9889 | Val Accuracy 0.7306
# Epoch 00155 | Time(s) 0.0651 | Train Loss 0.0684 | Val Loss 1.2709 | Train Accuracy 0.9889 | Val Accuracy 0.7306
# Epoch 00156 | Time(s) 0.0651 | Train Loss 0.0670 | Val Loss 1.2757 | Train Accuracy 0.9889 | Val Accuracy 0.7288
# Epoch 00157 | Time(s) 0.0651 | Train Loss 0.0657 | Val Loss 1.2805 | Train Accuracy 0.9926 | Val Accuracy 0.7269
# Epoch 00158 | Time(s) 0.0651 | Train Loss 0.0644 | Val Loss 1.2853 | Train Accuracy 0.9926 | Val Accuracy 0.7269
# Epoch 00159 | Time(s) 0.0651 | Train Loss 0.0631 | Val Loss 1.2900 | Train Accuracy 0.9926 | Val Accuracy 0.7269
# Epoch 00160 | Time(s) 0.0651 | Train Loss 0.0619 | Val Loss 1.2947 | Train Accuracy 0.9926 | Val Accuracy 0.7269
# Epoch 00161 | Time(s) 0.0651 | Train Loss 0.0607 | Val Loss 1.2994 | Train Accuracy 0.9926 | Val Accuracy 0.7269
# Epoch 00162 | Time(s) 0.0651 | Train Loss 0.0595 | Val Loss 1.3040 | Train Accuracy 0.9926 | Val Accuracy 0.7269
# Epoch 00163 | Time(s) 0.0651 | Train Loss 0.0584 | Val Loss 1.3087 | Train Accuracy 0.9926 | Val Accuracy 0.7251
# Epoch 00164 | Time(s) 0.0651 | Train Loss 0.0573 | Val Loss 1.3133 | Train Accuracy 0.9926 | Val Accuracy 0.7251
# Epoch 00165 | Time(s) 0.0651 | Train Loss 0.0562 | Val Loss 1.3180 | Train Accuracy 0.9926 | Val Accuracy 0.7251
# Epoch 00166 | Time(s) 0.0651 | Train Loss 0.0551 | Val Loss 1.3226 | Train Accuracy 0.9926 | Val Accuracy 0.7251
# Epoch 00167 | Time(s) 0.0651 | Train Loss 0.0541 | Val Loss 1.3272 | Train Accuracy 0.9926 | Val Accuracy 0.7251
# Epoch 00168 | Time(s) 0.0651 | Train Loss 0.0531 | Val Loss 1.3318 | Train Accuracy 0.9926 | Val Accuracy 0.7251
# Epoch 00169 | Time(s) 0.0651 | Train Loss 0.0522 | Val Loss 1.3364 | Train Accuracy 0.9926 | Val Accuracy 0.7214
# Epoch 00170 | Time(s) 0.0651 | Train Loss 0.0513 | Val Loss 1.3409 | Train Accuracy 0.9926 | Val Accuracy 0.7214
# Epoch 00171 | Time(s) 0.0651 | Train Loss 0.0503 | Val Loss 1.3454 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00172 | Time(s) 0.0651 | Train Loss 0.0495 | Val Loss 1.3499 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00173 | Time(s) 0.0651 | Train Loss 0.0486 | Val Loss 1.3543 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00174 | Time(s) 0.0651 | Train Loss 0.0478 | Val Loss 1.3588 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00175 | Time(s) 0.0651 | Train Loss 0.0470 | Val Loss 1.3632 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00176 | Time(s) 0.0651 | Train Loss 0.0462 | Val Loss 1.3677 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00177 | Time(s) 0.0651 | Train Loss 0.0454 | Val Loss 1.3721 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00178 | Time(s) 0.0651 | Train Loss 0.0446 | Val Loss 1.3764 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00179 | Time(s) 0.0651 | Train Loss 0.0439 | Val Loss 1.3808 | Train Accuracy 0.9926 | Val Accuracy 0.7214
# Epoch 00180 | Time(s) 0.0651 | Train Loss 0.0432 | Val Loss 1.3851 | Train Accuracy 0.9926 | Val Accuracy 0.7214
# Epoch 00181 | Time(s) 0.0651 | Train Loss 0.0425 | Val Loss 1.3894 | Train Accuracy 0.9926 | Val Accuracy 0.7214
# Epoch 00182 | Time(s) 0.0650 | Train Loss 0.0418 | Val Loss 1.3937 | Train Accuracy 0.9926 | Val Accuracy 0.7214
# Epoch 00183 | Time(s) 0.0650 | Train Loss 0.0412 | Val Loss 1.3980 | Train Accuracy 0.9926 | Val Accuracy 0.7214
# Epoch 00184 | Time(s) 0.0650 | Train Loss 0.0405 | Val Loss 1.4022 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00185 | Time(s) 0.0650 | Train Loss 0.0399 | Val Loss 1.4064 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00186 | Time(s) 0.0650 | Train Loss 0.0393 | Val Loss 1.4106 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00187 | Time(s) 0.0651 | Train Loss 0.0387 | Val Loss 1.4147 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00188 | Time(s) 0.0650 | Train Loss 0.0381 | Val Loss 1.4189 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00189 | Time(s) 0.0650 | Train Loss 0.0375 | Val Loss 1.4230 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00190 | Time(s) 0.0650 | Train Loss 0.0370 | Val Loss 1.4271 | Train Accuracy 0.9926 | Val Accuracy 0.7196
# Epoch 00191 | Time(s) 0.0650 | Train Loss 0.0364 | Val Loss 1.4312 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00192 | Time(s) 0.0650 | Train Loss 0.0359 | Val Loss 1.4353 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00193 | Time(s) 0.0651 | Train Loss 0.0354 | Val Loss 1.4393 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00194 | Time(s) 0.0651 | Train Loss 0.0349 | Val Loss 1.4433 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00195 | Time(s) 0.0650 | Train Loss 0.0344 | Val Loss 1.4473 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00196 | Time(s) 0.0650 | Train Loss 0.0339 | Val Loss 1.4513 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00197 | Time(s) 0.0650 | Train Loss 0.0335 | Val Loss 1.4553 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00198 | Time(s) 0.0651 | Train Loss 0.0330 | Val Loss 1.4592 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Epoch 00199 | Time(s) 0.0651 | Train Loss 0.0326 | Val Loss 1.4632 | Train Accuracy 0.9926 | Val Accuracy 0.7177
# Evaluation on stationary graphs!
# Best Testing Accuracy: 79.64%
# Test F1 Score: 79.58%
# The distributions of groundtruth classes:
#  [250 159 299 576 284 202 126]
# The distributions of predicted classes:
#  [253 122 303 559 324 234 101]
# The normalized entropy: 39.04% (±29.16%)
# Y_pred/Y_pred_sm.shape:  torch.Size([2708]) torch.Size([2708, 7])

# %% [markdown]
# ## Implement random perturbations on victim nodes

# %%
# ---Simulate Non-malicious random connections---
graph_rc, target_nodes_list, target_mask = \
    random_connections(graph, test_mask, SAMPLE_RATE, PERT_RATE, TARGET_CLASS)
feat_rc = graph_rc.ndata['feat']

# ---Initialize the node classifier---
print("Initialize the node classifier...")
# Setup the GPU if necessary
if GPU < 0:
    print("Using CPU!")
    cuda = False
else:
    print("Using GPU!")
    cuda = True
    torch.cuda.set_device(GPU)
    graph_rc = graph_rc.to('cuda')
    feat_rc = feat_rc.cuda()
    target_mask = target_mask.cuda()
# Create the trained model    
model = GNN(g=graph_rc,
            in_feats=feat_rc.shape[1],
            n_hidden=N_HIDDEN,
            n_classes=len(torch.unique(label)),
            n_layers=N_LAYERS,
            activation=F.relu,
            dropout=DROPOUT,
            model_name=model_name,
            aggregator_type=kwargs_dicts[model_name][0],
            n_filter=kwargs_dicts[model_name][1],
            n_heads=kwargs_dicts[model_name][2])
if cuda: # if GPU is available
    model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
# Path for saving the parameters
path = 'runs/{0}_{1}/'.format(data_name, model_name) + 'model_best.pth.tar'

# ---Evaluation the trained GNN on the perturbed target nodes---
print("Evaluation on the target nodes.")
evaluation(model, optimizer, path, graph_rc, feat_rc, label, target_mask, cuda)

# ---Output the perturbed graph and the predictions---
print("Save the perturbed graph and the target mask.")
if cuda:
    graph_rc, target_mask = graph_rc.cpu(), target_mask.cpu()
dump_pickle(dirs_attack+'G_rdm_C{0}_{1}_{2}.pkl' \
            .format(TARGET_CLASS, data_name, model_name), \
            [graph_rc, target_nodes_list, target_mask])
print("Generate predicted labels after perturbation.")
Y_pred, Y_pred_sm = prediction(model, optimizer, path, graph_rc, feat_rc)
if cuda:
    Y_pred, Y_pred_sm = Y_pred.cpu(), Y_pred_sm.cpu()
dump_pickle('../data/noisy_label/Y_preds_rdmPert.pkl', [Y_pred, Y_pred_sm])
print("Y_pred/Y_pred_sm.shape: ", Y_pred.shape, Y_pred_sm.shape)
# Out:
# time:  0.03683209419250488
# Initialize the node classifier...
# Using CPU!
# Evaluation on the target nodes.
# Best Testing Accuracy: 48.95%
# Test F1 Score: 41.97%
# The distributions of groundtruth classes:
#  [22 11 27 67 32 22  9]
# The distributions of predicted classes:
#  [  6   1  11 160  10   0   2]
# The normalized entropy: 9.24% (±19.48%)
# Save the perturbed graph and the target mask.
# Generate predicted labels after perturbation.
# Y_pred/Y_pred_sm.shape:  torch.Size([2708]) torch.Size([2708, 7])

# %% [markdown]
# ## Employ LInDT model to infer labels

# %%
# load the perturbed graphs and the corresponding predicted labels
graph_name = 'G_rdm_C{0}_{1}_{2}.pkl'\
              .format(TARGET_CLASS, data_name, model_name)
graph, _, target_mask = read_pickle(dirs_attack+graph_name)
feat = graph.ndata['feat']
Y_pred, Y_pred_sm = read_pickle('../data/noisy_label/Y_preds_rdmPert.pkl')
# Reload the clean predicted labels for inference
Y_cpred, Y_cpred_sm = read_pickle('../data/noisy_label/Y_preds.pkl')
# Convert tensor to numpy array
Y_gt, Y_cpred, Y_noisy, Y_pred, Y_pred_sm, Y_cpred_sm = \
    label.numpy(), Y_cpred.numpy(), Y_noisy.numpy(), Y_pred.numpy(), \
    Y_pred_sm.detach().numpy(), Y_cpred_sm.detach().numpy()

# ---Initialize the initial warm-up transition matrix---
print("Initialize the warm-up transition matrix...")
Y_pred_sm_train = Y_cpred_sm[train_mask]  # predicted probability table (num_samples, num_classes)
Y_noisy_train = Y_noisy[train_mask]  # noisy labels
NUM_CLASSES = len(set(label.numpy()))
print("NUM_CLASSES: ", NUM_CLASSES)
TM_warmup = gen_init_trans_matrix(Y_pred_sm_train, Y_noisy_train, NUM_CLASSES)
print("The shape of warm-up TM is: ", TM_warmup.shape)

# ---Setup the gpu if necessary---
if GPU < 0:
    print("Using CPU!")
    cuda = False
else:
    print("Using GPU!")
    cuda = True
    torch.cuda.set_device(GPU)
    graph = graph.to('cuda')
    feat = feat.cuda()

# ---Initialize the node classifier---
print("Initialize the node classifier...")
model = GNN(g=graph,
            in_feats=feat.shape[1],
            n_hidden=N_HIDDEN,
            n_classes=len(torch.unique(label)),
            n_layers=N_LAYERS,
            activation=F.relu,
            dropout=DROPOUT,
            model_name=model_name,
            aggregator_type=kwargs_dicts[model_name][0],
            n_filter=kwargs_dicts[model_name][1],
            n_heads=kwargs_dicts[model_name][2])
if cuda:  # if gpu is available
    model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
# Path for saving the parameters
dirs = 'runs/{0}_{1}/'.format(data_name, model_name)
path = dirs + 'model_best.pth.tar'

# --- Label Inference jointly using Dirichlet and Topological sampling ---
if is_inferable:
    print("Infer the label...")
    Y_ssup_dict = {"pseudo": Y_cpred, "noise": Y_noisy}
    timer_0 = time.time()
    ss = LInDT(ALPHA)  # Y_noisy or Y_cpred
    Y_infer, C_new, _ = \
        ss.infer(model, optimizer, dirs, graph, feat, train_mask, val_mask, \
                 Y_pred, Y_pred_sm, Y_ssup_dict[infer_type], Y_gt, TM_warmup, \
                 NUM_RETRAIN, GPU, NUM_EPS, WARMUP_STEP, \
                 is_alert, is_dynamic_phi, Kernel_Type, is_dynamic_alpha)
    runtime = time.time() - timer_0
    print("\n Runtime: ", runtime)
    print("Y_inferred: \n {0} \n C_new: \n {1}".format(Y_infer, C_new))
print("Evaluation after inference:")
Y_infer, C_new, _ = read_pickle('../data/noisy_label/Y_C_RUN.pkl')  # array
_, cat_dist = prediction(model, optimizer, path, graph, feat)  # tensor
# Evaluation on test/target graph
mask_dict = {"test": test_mask, "target": target_mask}
assert len(mask_dict) > 0
for mask_name, mask in mask_dict.items():
    Y_gt_mask = label[mask].numpy()
    Y_infer_mask = Y_infer[mask]
    cat_dist_mask = cat_dist[mask].cpu() if cuda else cat_dist[mask]
    cat_dist_mask = cat_dist_mask.detach().numpy()
    acc_infer = accuracy_score(Y_gt_mask, Y_infer_mask)
    print("Accuracy of Y_infer on {} nodes: {:.2%}.".format(mask_name, acc_infer))
    f1_macro = f1_score(Y_gt_mask, Y_infer_mask, average='macro')
    f1_weighted = f1_score(Y_gt_mask, Y_infer_mask, average='weighted')
    print("F1 score (macro) of Y_infer on {} nodes: {:.2%}.".format(mask_name, f1_macro))
    print("F1 score (weighted) of Y_infer on {} nodes: {:.2%}.".format(mask_name, f1_weighted))
    total_entropy = entropy(cat_dist_mask, axis=1)
    normalized_entropy = total_entropy / np.log(cat_dist.shape[1])
    print("The normalized entropy on {} nodes: {:.2%}."\
          .format(mask_name, np.mean(normalized_entropy)))
    print("-"*30)
# Out:
# Initialize the warm-up transition matrix...
# NUM_CLASSES:  7
# The shape of warm-up TM is:  (7, 7)
# Using CPU!
# Initialize the node classifier...
# Infer the label...
# Update the model in step 0:
# /Users/junzhuang/opt/miniconda3/envs/py39/lib/python3.9/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# Epoch 00105 | Time(s) 0.0773 | Train Loss 1.6649 | Val Loss 2.5851 | Train Accuracy 0.8296 | Val Accuracy 0.7731
# Epoch 00106 | Time(s) 0.0737 | Train Loss 0.8789 | Val Loss 1.4896 | Train Accuracy 0.8778 | Val Accuracy 0.8100
# Epoch 00107 | Time(s) 0.0727 | Train Loss 0.3928 | Val Loss 0.7559 | Train Accuracy 0.9185 | Val Accuracy 0.8339
# Epoch 00108 | Time(s) 0.0730 | Train Loss 1.0155 | Val Loss 1.4238 | Train Accuracy 0.8148 | Val Accuracy 0.7011
# Epoch 00109 | Time(s) 0.0724 | Train Loss 0.9335 | Val Loss 1.2580 | Train Accuracy 0.8407 | Val Accuracy 0.7306
# Epoch 00110 | Time(s) 0.0717 | Train Loss 0.5297 | Val Loss 0.8003 | Train Accuracy 0.8963 | Val Accuracy 0.8118
# Epoch 00111 | Time(s) 0.0715 | Train Loss 0.3592 | Val Loss 0.5828 | Train Accuracy 0.9296 | Val Accuracy 0.8653
# Epoch 00112 | Time(s) 0.0713 | Train Loss 0.4839 | Val Loss 0.8239 | Train Accuracy 0.9111 | Val Accuracy 0.8524
# Epoch 00113 | Time(s) 0.0708 | Train Loss 0.5917 | Val Loss 1.0375 | Train Accuracy 0.8889 | Val Accuracy 0.8303
# Epoch 00114 | Time(s) 0.0707 | Train Loss 0.5620 | Val Loss 1.0623 | Train Accuracy 0.9037 | Val Accuracy 0.8376
# Epoch 00115 | Time(s) 0.0710 | Train Loss 0.4470 | Val Loss 0.9407 | Train Accuracy 0.9185 | Val Accuracy 0.8395
# Epoch 00116 | Time(s) 0.0716 | Train Loss 0.3687 | Val Loss 0.8402 | Train Accuracy 0.9074 | Val Accuracy 0.8376
# Epoch 00117 | Time(s) 0.0717 | Train Loss 0.4710 | Val Loss 0.9886 | Train Accuracy 0.8741 | Val Accuracy 0.7694
# Epoch 00118 | Time(s) 0.0716 | Train Loss 0.4524 | Val Loss 0.9424 | Train Accuracy 0.8889 | Val Accuracy 0.7768
# Epoch 00119 | Time(s) 0.0713 | Train Loss 0.2892 | Val Loss 0.6364 | Train Accuracy 0.9185 | Val Accuracy 0.8358
# Epoch 00120 | Time(s) 0.0709 | Train Loss 0.2547 | Val Loss 0.5539 | Train Accuracy 0.9407 | Val Accuracy 0.8616
# Epoch 00121 | Time(s) 0.0705 | Train Loss 0.3015 | Val Loss 0.5792 | Train Accuracy 0.9481 | Val Accuracy 0.8487
# Epoch 00122 | Time(s) 0.0701 | Train Loss 0.3456 | Val Loss 0.6104 | Train Accuracy 0.9333 | Val Accuracy 0.8524
# Epoch 00123 | Time(s) 0.0697 | Train Loss 0.3626 | Val Loss 0.6152 | Train Accuracy 0.9185 | Val Accuracy 0.8358
# Epoch 00124 | Time(s) 0.0694 | Train Loss 0.3406 | Val Loss 0.5758 | Train Accuracy 0.9296 | Val Accuracy 0.8432
# Epoch 00125 | Time(s) 0.0691 | Train Loss 0.2793 | Val Loss 0.4883 | Train Accuracy 0.9370 | Val Accuracy 0.8764
# Epoch 00126 | Time(s) 0.0689 | Train Loss 0.2252 | Val Loss 0.4248 | Train Accuracy 0.9593 | Val Accuracy 0.9041
# Epoch 00127 | Time(s) 0.0688 | Train Loss 0.2117 | Val Loss 0.4188 | Train Accuracy 0.9630 | Val Accuracy 0.9004
# Epoch 00128 | Time(s) 0.0687 | Train Loss 0.2372 | Val Loss 0.4952 | Train Accuracy 0.9407 | Val Accuracy 0.8764
# Epoch 00129 | Time(s) 0.0685 | Train Loss 0.2514 | Val Loss 0.5440 | Train Accuracy 0.9407 | Val Accuracy 0.8653
# Epoch 00130 | Time(s) 0.0683 | Train Loss 0.2389 | Val Loss 0.5385 | Train Accuracy 0.9519 | Val Accuracy 0.8801
# Epoch 00131 | Time(s) 0.0681 | Train Loss 0.2395 | Val Loss 0.5613 | Train Accuracy 0.9519 | Val Accuracy 0.8856
# Epoch 00132 | Time(s) 0.0679 | Train Loss 0.2460 | Val Loss 0.5650 | Train Accuracy 0.9556 | Val Accuracy 0.8838
# Epoch 00133 | Time(s) 0.0677 | Train Loss 0.2254 | Val Loss 0.5157 | Train Accuracy 0.9630 | Val Accuracy 0.8875
# Epoch 00134 | Time(s) 0.0676 | Train Loss 0.1958 | Val Loss 0.4389 | Train Accuracy 0.9741 | Val Accuracy 0.8985
# Epoch 00135 | Time(s) 0.0675 | Train Loss 0.1916 | Val Loss 0.3866 | Train Accuracy 0.9815 | Val Accuracy 0.9114
# Epoch 00136 | Time(s) 0.0673 | Train Loss 0.2010 | Val Loss 0.3738 | Train Accuracy 0.9667 | Val Accuracy 0.9225
# Epoch 00137 | Time(s) 0.0672 | Train Loss 0.2059 | Val Loss 0.3749 | Train Accuracy 0.9593 | Val Accuracy 0.9225
# Epoch 00138 | Time(s) 0.0671 | Train Loss 0.2008 | Val Loss 0.3753 | Train Accuracy 0.9593 | Val Accuracy 0.9225
# Epoch 00139 | Time(s) 0.0670 | Train Loss 0.1910 | Val Loss 0.3704 | Train Accuracy 0.9778 | Val Accuracy 0.9225
# Epoch 00140 | Time(s) 0.0669 | Train Loss 0.1887 | Val Loss 0.3806 | Train Accuracy 0.9852 | Val Accuracy 0.9244
# Epoch 00141 | Time(s) 0.0668 | Train Loss 0.1871 | Val Loss 0.3932 | Train Accuracy 0.9852 | Val Accuracy 0.9207
# Epoch 00142 | Time(s) 0.0668 | Train Loss 0.1802 | Val Loss 0.3984 | Train Accuracy 0.9852 | Val Accuracy 0.9096
# Epoch 00143 | Time(s) 0.0668 | Train Loss 0.1741 | Val Loss 0.3982 | Train Accuracy 0.9815 | Val Accuracy 0.9151
# Epoch 00144 | Time(s) 0.0668 | Train Loss 0.1773 | Val Loss 0.4036 | Train Accuracy 0.9815 | Val Accuracy 0.9096
# Epoch 00145 | Time(s) 0.0667 | Train Loss 0.1814 | Val Loss 0.4124 | Train Accuracy 0.9815 | Val Accuracy 0.9041
# Epoch 00146 | Time(s) 0.0667 | Train Loss 0.1793 | Val Loss 0.4108 | Train Accuracy 0.9815 | Val Accuracy 0.9077
# Epoch 00147 | Time(s) 0.0666 | Train Loss 0.1727 | Val Loss 0.4025 | Train Accuracy 0.9815 | Val Accuracy 0.9114
# Epoch 00148 | Time(s) 0.0665 | Train Loss 0.1682 | Val Loss 0.3973 | Train Accuracy 0.9815 | Val Accuracy 0.9188
# Epoch 00149 | Time(s) 0.0665 | Train Loss 0.1684 | Val Loss 0.3921 | Train Accuracy 0.9815 | Val Accuracy 0.9170
# Epoch 00150 | Time(s) 0.0665 | Train Loss 0.1669 | Val Loss 0.3797 | Train Accuracy 0.9852 | Val Accuracy 0.9207
# Epoch 00151 | Time(s) 0.0665 | Train Loss 0.1627 | Val Loss 0.3630 | Train Accuracy 0.9852 | Val Accuracy 0.9317
# Epoch 00152 | Time(s) 0.0664 | Train Loss 0.1615 | Val Loss 0.3504 | Train Accuracy 0.9852 | Val Accuracy 0.9373
# Epoch 00153 | Time(s) 0.0665 | Train Loss 0.1631 | Val Loss 0.3448 | Train Accuracy 0.9852 | Val Accuracy 0.9410
# Epoch 00154 | Time(s) 0.0664 | Train Loss 0.1626 | Val Loss 0.3424 | Train Accuracy 0.9852 | Val Accuracy 0.9410
# Epoch 00155 | Time(s) 0.0664 | Train Loss 0.1594 | Val Loss 0.3417 | Train Accuracy 0.9852 | Val Accuracy 0.9373
# Epoch 00156 | Time(s) 0.0664 | Train Loss 0.1561 | Val Loss 0.3447 | Train Accuracy 0.9852 | Val Accuracy 0.9336
# Epoch 00157 | Time(s) 0.0663 | Train Loss 0.1553 | Val Loss 0.3514 | Train Accuracy 0.9852 | Val Accuracy 0.9336
# Epoch 00158 | Time(s) 0.0662 | Train Loss 0.1545 | Val Loss 0.3570 | Train Accuracy 0.9852 | Val Accuracy 0.9280
# Epoch 00159 | Time(s) 0.0662 | Train Loss 0.1522 | Val Loss 0.3584 | Train Accuracy 0.9852 | Val Accuracy 0.9280
# Epoch 00160 | Time(s) 0.0662 | Train Loss 0.1507 | Val Loss 0.3575 | Train Accuracy 0.9852 | Val Accuracy 0.9280
# Epoch 00161 | Time(s) 0.0661 | Train Loss 0.1506 | Val Loss 0.3570 | Train Accuracy 0.9852 | Val Accuracy 0.9280
# Epoch 00162 | Time(s) 0.0662 | Train Loss 0.1501 | Val Loss 0.3564 | Train Accuracy 0.9852 | Val Accuracy 0.9262
# Epoch 00163 | Time(s) 0.0662 | Train Loss 0.1485 | Val Loss 0.3548 | Train Accuracy 0.9852 | Val Accuracy 0.9225
# Epoch 00164 | Time(s) 0.0662 | Train Loss 0.1464 | Val Loss 0.3527 | Train Accuracy 0.9852 | Val Accuracy 0.9225
# Accuracy of inferred labels:  0.7896678966789668
# The normalized entropy: 26.04%.
# Update the model in step 10:
# Epoch 00154 | Time(s) 0.0713 | Train Loss 0.1926 | Val Loss 0.3668 | Train Accuracy 0.9667 | Val Accuracy 0.9299
# Epoch 00155 | Time(s) 0.0695 | Train Loss 0.1797 | Val Loss 0.3444 | Train Accuracy 0.9667 | Val Accuracy 0.9410
# /Users/junzhuang/opt/miniconda3/envs/py39/lib/python3.9/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# Epoch 00156 | Time(s) 0.0704 | Train Loss 0.1645 | Val Loss 0.3166 | Train Accuracy 0.9815 | Val Accuracy 0.9520
# Epoch 00157 | Time(s) 0.0699 | Train Loss 0.1564 | Val Loss 0.2966 | Train Accuracy 0.9926 | Val Accuracy 0.9594
# Epoch 00158 | Time(s) 0.0687 | Train Loss 0.1563 | Val Loss 0.2889 | Train Accuracy 0.9963 | Val Accuracy 0.9557
# Epoch 00159 | Time(s) 0.0693 | Train Loss 0.1600 | Val Loss 0.2891 | Train Accuracy 0.9778 | Val Accuracy 0.9594
# Epoch 00160 | Time(s) 0.0685 | Train Loss 0.1606 | Val Loss 0.2901 | Train Accuracy 0.9704 | Val Accuracy 0.9631
# Epoch 00161 | Time(s) 0.0680 | Train Loss 0.1567 | Val Loss 0.2906 | Train Accuracy 0.9704 | Val Accuracy 0.9557
# Epoch 00162 | Time(s) 0.0675 | Train Loss 0.1521 | Val Loss 0.2934 | Train Accuracy 0.9778 | Val Accuracy 0.9483
# Epoch 00163 | Time(s) 0.0670 | Train Loss 0.1468 | Val Loss 0.2968 | Train Accuracy 0.9852 | Val Accuracy 0.9465
# Epoch 00164 | Time(s) 0.0665 | Train Loss 0.1422 | Val Loss 0.2992 | Train Accuracy 0.9926 | Val Accuracy 0.9446
# Epoch 00165 | Time(s) 0.0663 | Train Loss 0.1420 | Val Loss 0.3034 | Train Accuracy 0.9889 | Val Accuracy 0.9373
# Epoch 00166 | Time(s) 0.0661 | Train Loss 0.1444 | Val Loss 0.3095 | Train Accuracy 0.9889 | Val Accuracy 0.9428
# Epoch 00167 | Time(s) 0.0660 | Train Loss 0.1453 | Val Loss 0.3124 | Train Accuracy 0.9926 | Val Accuracy 0.9391
# Epoch 00168 | Time(s) 0.0660 | Train Loss 0.1426 | Val Loss 0.3077 | Train Accuracy 0.9926 | Val Accuracy 0.9410
# Epoch 00169 | Time(s) 0.0659 | Train Loss 0.1378 | Val Loss 0.2988 | Train Accuracy 0.9926 | Val Accuracy 0.9446
# Epoch 00170 | Time(s) 0.0658 | Train Loss 0.1338 | Val Loss 0.2915 | Train Accuracy 0.9926 | Val Accuracy 0.9465
# Epoch 00171 | Time(s) 0.0656 | Train Loss 0.1331 | Val Loss 0.2876 | Train Accuracy 0.9926 | Val Accuracy 0.9520
# Epoch 00172 | Time(s) 0.0655 | Train Loss 0.1343 | Val Loss 0.2848 | Train Accuracy 0.9926 | Val Accuracy 0.9483
# Epoch 00173 | Time(s) 0.0654 | Train Loss 0.1340 | Val Loss 0.2810 | Train Accuracy 0.9889 | Val Accuracy 0.9502
# Epoch 00174 | Time(s) 0.0653 | Train Loss 0.1326 | Val Loss 0.2773 | Train Accuracy 0.9926 | Val Accuracy 0.9557
# Epoch 00175 | Time(s) 0.0674 | Train Loss 0.1309 | Val Loss 0.2753 | Train Accuracy 0.9926 | Val Accuracy 0.9539
# Epoch 00176 | Time(s) 0.0673 | Train Loss 0.1288 | Val Loss 0.2760 | Train Accuracy 0.9926 | Val Accuracy 0.9520
# Epoch 00177 | Time(s) 0.0671 | Train Loss 0.1271 | Val Loss 0.2799 | Train Accuracy 0.9963 | Val Accuracy 0.9483
# Epoch 00178 | Time(s) 0.0669 | Train Loss 0.1265 | Val Loss 0.2859 | Train Accuracy 0.9926 | Val Accuracy 0.9446
# Epoch 00179 | Time(s) 0.0669 | Train Loss 0.1264 | Val Loss 0.2914 | Train Accuracy 0.9926 | Val Accuracy 0.9428
# Epoch 00180 | Time(s) 0.0668 | Train Loss 0.1260 | Val Loss 0.2936 | Train Accuracy 0.9926 | Val Accuracy 0.9428
# Epoch 00181 | Time(s) 0.0667 | Train Loss 0.1245 | Val Loss 0.2912 | Train Accuracy 0.9926 | Val Accuracy 0.9410
# Epoch 00182 | Time(s) 0.0666 | Train Loss 0.1225 | Val Loss 0.2853 | Train Accuracy 0.9926 | Val Accuracy 0.9428
# Epoch 00183 | Time(s) 0.0664 | Train Loss 0.1210 | Val Loss 0.2788 | Train Accuracy 0.9926 | Val Accuracy 0.9465
# Epoch 00184 | Time(s) 0.0664 | Train Loss 0.1203 | Val Loss 0.2740 | Train Accuracy 0.9963 | Val Accuracy 0.9465
# Epoch 00185 | Time(s) 0.0664 | Train Loss 0.1199 | Val Loss 0.2715 | Train Accuracy 0.9926 | Val Accuracy 0.9465
# Epoch 00186 | Time(s) 0.0663 | Train Loss 0.1191 | Val Loss 0.2711 | Train Accuracy 0.9926 | Val Accuracy 0.9446
# Epoch 00187 | Time(s) 0.0662 | Train Loss 0.1180 | Val Loss 0.2721 | Train Accuracy 0.9963 | Val Accuracy 0.9446
# Epoch 00188 | Time(s) 0.0661 | Train Loss 0.1169 | Val Loss 0.2738 | Train Accuracy 0.9963 | Val Accuracy 0.9446
# Epoch 00189 | Time(s) 0.0660 | Train Loss 0.1158 | Val Loss 0.2752 | Train Accuracy 0.9926 | Val Accuracy 0.9465
# Epoch 00190 | Time(s) 0.0659 | Train Loss 0.1148 | Val Loss 0.2756 | Train Accuracy 0.9926 | Val Accuracy 0.9465
# Epoch 00191 | Time(s) 0.0659 | Train Loss 0.1141 | Val Loss 0.2754 | Train Accuracy 0.9926 | Val Accuracy 0.9446
# Epoch 00192 | Time(s) 0.0661 | Train Loss 0.1135 | Val Loss 0.2747 | Train Accuracy 0.9926 | Val Accuracy 0.9428
# Epoch 00193 | Time(s) 0.0661 | Train Loss 0.1128 | Val Loss 0.2736 | Train Accuracy 0.9926 | Val Accuracy 0.9446
# Epoch 00194 | Time(s) 0.0666 | Train Loss 0.1118 | Val Loss 0.2720 | Train Accuracy 0.9926 | Val Accuracy 0.9446
# Epoch 00195 | Time(s) 0.0671 | Train Loss 0.1107 | Val Loss 0.2702 | Train Accuracy 0.9963 | Val Accuracy 0.9465
# Epoch 00196 | Time(s) 0.0674 | Train Loss 0.1098 | Val Loss 0.2686 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00197 | Time(s) 0.0674 | Train Loss 0.1090 | Val Loss 0.2670 | Train Accuracy 0.9963 | Val Accuracy 0.9465
# Epoch 00198 | Time(s) 0.0675 | Train Loss 0.1083 | Val Loss 0.2652 | Train Accuracy 0.9963 | Val Accuracy 0.9446
# Epoch 00199 | Time(s) 0.0674 | Train Loss 0.1075 | Val Loss 0.2632 | Train Accuracy 0.9963 | Val Accuracy 0.9446
# Epoch 00200 | Time(s) 0.0674 | Train Loss 0.1066 | Val Loss 0.2615 | Train Accuracy 0.9963 | Val Accuracy 0.9465
# Epoch 00201 | Time(s) 0.0673 | Train Loss 0.1058 | Val Loss 0.2604 | Train Accuracy 0.9963 | Val Accuracy 0.9483
# Epoch 00202 | Time(s) 0.0672 | Train Loss 0.1049 | Val Loss 0.2602 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00203 | Time(s) 0.0672 | Train Loss 0.1041 | Val Loss 0.2606 | Train Accuracy 1.0000 | Val Accuracy 0.9502
# Epoch 00204 | Time(s) 0.0671 | Train Loss 0.1034 | Val Loss 0.2613 | Train Accuracy 0.9963 | Val Accuracy 0.9483
# Epoch 00205 | Time(s) 0.0671 | Train Loss 0.1026 | Val Loss 0.2616 | Train Accuracy 0.9926 | Val Accuracy 0.9502
# Epoch 00206 | Time(s) 0.0670 | Train Loss 0.1019 | Val Loss 0.2611 | Train Accuracy 0.9926 | Val Accuracy 0.9483
# Epoch 00207 | Time(s) 0.0670 | Train Loss 0.1011 | Val Loss 0.2598 | Train Accuracy 0.9926 | Val Accuracy 0.9483
# Epoch 00208 | Time(s) 0.0669 | Train Loss 0.1003 | Val Loss 0.2578 | Train Accuracy 0.9963 | Val Accuracy 0.9520
# Epoch 00209 | Time(s) 0.0668 | Train Loss 0.0995 | Val Loss 0.2557 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00210 | Time(s) 0.0668 | Train Loss 0.0988 | Val Loss 0.2539 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00211 | Time(s) 0.0667 | Train Loss 0.0981 | Val Loss 0.2528 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00212 | Time(s) 0.0667 | Train Loss 0.0973 | Val Loss 0.2522 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00213 | Time(s) 0.0666 | Train Loss 0.0966 | Val Loss 0.2521 | Train Accuracy 0.9963 | Val Accuracy 0.9483
# Accuracy of inferred labels:  0.8118081180811808
# The normalized entropy: 30.36%.
# Update the model in step 20:
# Epoch 00161 | Time(s) 0.0703 | Train Loss 0.1621 | Val Loss 0.2925 | Train Accuracy 0.9778 | Val Accuracy 0.9557
# Epoch 00162 | Time(s) 0.0706 | Train Loss 0.1570 | Val Loss 0.2899 | Train Accuracy 0.9815 | Val Accuracy 0.9539
# /Users/junzhuang/opt/miniconda3/envs/py39/lib/python3.9/site-packages/torch/autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# Epoch 00163 | Time(s) 0.0792 | Train Loss 0.1473 | Val Loss 0.2823 | Train Accuracy 0.9815 | Val Accuracy 0.9557
# Epoch 00164 | Time(s) 0.0837 | Train Loss 0.1416 | Val Loss 0.2807 | Train Accuracy 0.9815 | Val Accuracy 0.9594
# Epoch 00165 | Time(s) 0.0827 | Train Loss 0.1404 | Val Loss 0.2892 | Train Accuracy 0.9815 | Val Accuracy 0.9502
# Epoch 00166 | Time(s) 0.0799 | Train Loss 0.1395 | Val Loss 0.2997 | Train Accuracy 0.9852 | Val Accuracy 0.9465
# Epoch 00167 | Time(s) 0.0776 | Train Loss 0.1366 | Val Loss 0.3015 | Train Accuracy 0.9852 | Val Accuracy 0.9483
# Epoch 00168 | Time(s) 0.0760 | Train Loss 0.1327 | Val Loss 0.2963 | Train Accuracy 0.9852 | Val Accuracy 0.9483
# Epoch 00169 | Time(s) 0.0750 | Train Loss 0.1298 | Val Loss 0.2910 | Train Accuracy 0.9889 | Val Accuracy 0.9520
# Epoch 00170 | Time(s) 0.0741 | Train Loss 0.1282 | Val Loss 0.2891 | Train Accuracy 0.9926 | Val Accuracy 0.9428
# Epoch 00171 | Time(s) 0.0735 | Train Loss 0.1271 | Val Loss 0.2898 | Train Accuracy 0.9889 | Val Accuracy 0.9354
# Epoch 00172 | Time(s) 0.0730 | Train Loss 0.1258 | Val Loss 0.2898 | Train Accuracy 0.9889 | Val Accuracy 0.9391
# Epoch 00173 | Time(s) 0.0725 | Train Loss 0.1248 | Val Loss 0.2894 | Train Accuracy 0.9889 | Val Accuracy 0.9410
# Epoch 00174 | Time(s) 0.0719 | Train Loss 0.1254 | Val Loss 0.2927 | Train Accuracy 0.9852 | Val Accuracy 0.9391
# Epoch 00175 | Time(s) 0.0716 | Train Loss 0.1245 | Val Loss 0.2947 | Train Accuracy 0.9852 | Val Accuracy 0.9446
# Epoch 00176 | Time(s) 0.0714 | Train Loss 0.1217 | Val Loss 0.2904 | Train Accuracy 0.9926 | Val Accuracy 0.9465
# Epoch 00177 | Time(s) 0.0710 | Train Loss 0.1212 | Val Loss 0.2881 | Train Accuracy 0.9963 | Val Accuracy 0.9465
# Epoch 00178 | Time(s) 0.0707 | Train Loss 0.1212 | Val Loss 0.2883 | Train Accuracy 0.9963 | Val Accuracy 0.9483
# Epoch 00179 | Time(s) 0.0704 | Train Loss 0.1204 | Val Loss 0.2882 | Train Accuracy 0.9963 | Val Accuracy 0.9465
# Epoch 00180 | Time(s) 0.0706 | Train Loss 0.1186 | Val Loss 0.2872 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00181 | Time(s) 0.0709 | Train Loss 0.1168 | Val Loss 0.2873 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00182 | Time(s) 0.0711 | Train Loss 0.1155 | Val Loss 0.2877 | Train Accuracy 0.9926 | Val Accuracy 0.9539
# Epoch 00183 | Time(s) 0.0713 | Train Loss 0.1143 | Val Loss 0.2848 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00184 | Time(s) 0.0710 | Train Loss 0.1127 | Val Loss 0.2784 | Train Accuracy 0.9963 | Val Accuracy 0.9502
# Epoch 00185 | Time(s) 0.0708 | Train Loss 0.1115 | Val Loss 0.2741 | Train Accuracy 0.9963 | Val Accuracy 0.9539
# Epoch 00186 | Time(s) 0.0705 | Train Loss 0.1109 | Val Loss 0.2734 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00187 | Time(s) 0.0703 | Train Loss 0.1102 | Val Loss 0.2732 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00188 | Time(s) 0.0702 | Train Loss 0.1090 | Val Loss 0.2723 | Train Accuracy 1.0000 | Val Accuracy 0.9539
# Epoch 00189 | Time(s) 0.0699 | Train Loss 0.1079 | Val Loss 0.2716 | Train Accuracy 0.9963 | Val Accuracy 0.9539
# Epoch 00190 | Time(s) 0.0697 | Train Loss 0.1072 | Val Loss 0.2722 | Train Accuracy 0.9963 | Val Accuracy 0.9576
# Epoch 00191 | Time(s) 0.0696 | Train Loss 0.1067 | Val Loss 0.2731 | Train Accuracy 0.9963 | Val Accuracy 0.9576
# Epoch 00192 | Time(s) 0.0694 | Train Loss 0.1061 | Val Loss 0.2725 | Train Accuracy 0.9963 | Val Accuracy 0.9613
# Epoch 00193 | Time(s) 0.0692 | Train Loss 0.1051 | Val Loss 0.2703 | Train Accuracy 0.9963 | Val Accuracy 0.9613
# Epoch 00194 | Time(s) 0.0691 | Train Loss 0.1041 | Val Loss 0.2677 | Train Accuracy 0.9963 | Val Accuracy 0.9557
# Epoch 00195 | Time(s) 0.0689 | Train Loss 0.1033 | Val Loss 0.2656 | Train Accuracy 0.9963 | Val Accuracy 0.9576
# Epoch 00196 | Time(s) 0.0688 | Train Loss 0.1026 | Val Loss 0.2638 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00197 | Time(s) 0.0686 | Train Loss 0.1017 | Val Loss 0.2620 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00198 | Time(s) 0.0686 | Train Loss 0.1008 | Val Loss 0.2599 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00199 | Time(s) 0.0685 | Train Loss 0.0999 | Val Loss 0.2580 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00200 | Time(s) 0.0684 | Train Loss 0.0991 | Val Loss 0.2567 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00201 | Time(s) 0.0683 | Train Loss 0.0983 | Val Loss 0.2556 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00202 | Time(s) 0.0682 | Train Loss 0.0975 | Val Loss 0.2540 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00203 | Time(s) 0.0681 | Train Loss 0.0967 | Val Loss 0.2522 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00204 | Time(s) 0.0680 | Train Loss 0.0959 | Val Loss 0.2508 | Train Accuracy 1.0000 | Val Accuracy 0.9539
# Epoch 00205 | Time(s) 0.0680 | Train Loss 0.0952 | Val Loss 0.2500 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00206 | Time(s) 0.0679 | Train Loss 0.0945 | Val Loss 0.2494 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00207 | Time(s) 0.0678 | Train Loss 0.0937 | Val Loss 0.2490 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00208 | Time(s) 0.0677 | Train Loss 0.0929 | Val Loss 0.2488 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00209 | Time(s) 0.0677 | Train Loss 0.0922 | Val Loss 0.2489 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 
| Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00238 | Time(s) 0.0679 | Train Loss 0.0739 | Val Loss 0.2237 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00239 | Time(s) 0.0679 | Train Loss 0.0733 | Val Loss 0.2229 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00240 | Time(s) 0.0679 | Train Loss 0.0728 | Val Loss 0.2221 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00241 | Time(s) 0.0679 | Train Loss 0.0722 | Val Loss 0.2214 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00242 | Time(s) 0.0679 | Train Loss 0.0717 | Val Loss 0.2209 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00243 | Time(s) 0.0679 | Train Loss 0.0711 | Val Loss 0.2206 | Train Accuracy 1.0000 | Val Accuracy 0.9576
# Epoch 00244 | Time(s) 0.0679 | Train Loss 0.0706 | Val Loss 0.2204 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00245 | Time(s) 0.0679 | Train Loss 0.0701 | Val Loss 0.2203 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00246 | Time(s) 0.0679 | Train Loss 0.0696 | Val Loss 0.2200 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00247 | Time(s) 0.0679 | Train Loss 0.0690 | Val Loss 0.2195 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00248 | Time(s) 0.0679 | Train Loss 0.0685 | Val Loss 0.2188 | Train Accuracy 1.0000 | Val Accuracy 0.9539
# Epoch 00249 | Time(s) 0.0679 | Train Loss 0.0680 | Val Loss 0.2182 | Train Accuracy 1.0000 | Val Accuracy 0.9539
# Epoch 00250 | Time(s) 0.0679 | Train Loss 0.0675 | Val Loss 0.2177 | Train Accuracy 1.0000 | Val Accuracy 0.9539
# Epoch 00251 | Time(s) 0.0679 | Train Loss 0.0670 | Val Loss 0.2172 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00252 | Time(s) 0.0679 | Train Loss 0.0665 | Val Loss 0.2168 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00253 | Time(s) 0.0679 | Train Loss 0.0660 | Val Loss 0.2165 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00254 | Time(s) 0.0679 | Train Loss 0.0655 | Val Loss 0.2161 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00255 | Time(s) 0.0679 | Train Loss 0.0651 | Val Loss 0.2156 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00256 | Time(s) 0.0679 | Train Loss 0.0646 | Val Loss 0.2151 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00257 | Time(s) 0.0679 | Train Loss 0.0641 | Val Loss 0.2145 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00258 | Time(s) 0.0679 | Train Loss 0.0636 | Val Loss 0.2140 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00259 | Time(s) 0.0679 | Train Loss 0.0632 | Val Loss 0.2136 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Epoch 00260 | Time(s) 0.0679 | Train Loss 0.0627 | Val Loss 0.2132 | Train Accuracy 1.0000 | Val Accuracy 0.9557
# Accuracy of inferred labels:  0.8173431734317343
# The normalized entropy: 27.04%.
#
#  Runtime:  51.480435371398926
# Y_inferred:
#  [5 4 4 ... 3 3 3]
#  C_new:
#  [[362.   0.   0.   0.   0.   0.   0.]
#  [  0. 168.   2.   0.   0.   0.   0.]
#  [  0.   0. 419.   0.   0.   0.   0.]
#  [  0.   1.   0. 791.   0.   0.   0.]
#  [  0.   0.   0.   0. 478.   0.   0.]
#  [  0.   0.   0.   0.   0. 337.   0.]
#  [  0.   0.   0.   0.   0.   0. 150.]]
# Evaluation after inference:
# Accuracy of Y_infer on test nodes: 79.64%.
# F1 score (macro) of Y_infer on test nodes: 78.30%.
# F1 score (weighted) of Y_infer on test nodes: 79.58%.
# The normalized entropy on test nodes: 27.49%.
# ------------------------------
# Accuracy of Y_infer on target nodes: 84.21%.
# F1 score (macro) of Y_infer on target nodes: 79.84%.
# F1 score (weighted) of Y_infer on target nodes: 83.76%.
# The normalized entropy on target nodes: 22.97%.
# ------------------------------
